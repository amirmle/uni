# %%
import numpy as np

# %%
data = [
    [165,130],
    [167,133],
    [180,150],
    [155,128],
    [212,151],
    [175,146],
    [190,150],
    [210,140],
    [200,148],
    [149,125],
    [158,133],
    [169,135],
    [170,150],
    [172,153],
    [159,128],
    [168,132],
    [174,149],
    [183,158],
    [215,150],
    [195,163],
    [180,156],
    [143,124],
    [240,170],
    [235,165],
    [192,160],
    [187,159],
   
]
data = np.array(data)

# %%
xy = 0
xx = 0
for i in data:
    xy += i[0]*i[1]
    xx +=i[0]*i[0]
    # print(xy)
    # print(xx)

w = xy / xx
print(w)
# Out:
# 0.7916415401825007

# %%
test = 185
y = w * test
print(y)
# Out:
# 146.45368493376262
